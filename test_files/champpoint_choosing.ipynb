# %%
import numpy as np
from math import pi
import matplotlib.pyplot as pl
from mpl_toolkits import mplot3d
import copy
import numpy.linalg as LA

from numpy import loadtxt
import os
import random
import csv
import pandas as pd
from datetime import datetime
import scipy
import scipy.interpolate as itp
import scipy.integrate as iint
from scipy.interpolate import interp1d

# %%
class necro:
    def __init__(self,**kwargs):
                
        # initialize damage category multipliers
        #----------------------------------------
        magic = 0
        fire = 0
        ice = 0
        lightning = 0
        physical = 0
        poison = 0
        disease = 0
        bleed = 0
        
        la = 0
        
        single = 0
        aoe = 0
        direct = 0
        dot = .15
        
        
        # magic, fire, ice, and lightning attributes
        #----------------------------------------
        
        
class toon:
    def __init__(self,eso_class,**kwargs):
        
        # buff kwargs (default to True)
        #----------------------------------------
        minor_berserk = kwargs.pop('minor_berserk',True)
        major_berserk = kwargs.pop('major_berserk',True)
        minor_slayer = kwargs.pop('minor_slayer',True)
        major_slayer = kwargs.pop('major_slayer',True)
        minor_sorcery = kwargs.pop('minor_sorcery',True)
        major_sorcery = kwargs.pop('major_sorcery',True)
        minor_prophecy = kwargs.pop('minor_prophecy',True)
        major_prophecy = kwargs.pop('major_prophecy',True)
        minor_force = kwargs.pop('minor_force',True)
        major_force = kwargs.pop('major_force',True)
        engulfing = kwargs.pop('engulfing',True)
        encratis = kwargs.pop('encratis',True)
        empower = kwargs.pop('empower',True)
        tong = kwargs.pop('tong',True)
        
        # champion points
        #----------------------------------------
        biting = kwargs.pop('biting',0)
        thaum = kwargs.pop('thaum',0)
        maa = kwargs.pop('maa',0)
        deadly = kwargs.pop('deadly',0)
        finesse = kwargs.pop('finesse',0)
        backstabber = kwargs.pop('backstabber',0)
        
        # weight breakdown
        #----------------------------------------
        light = kwargs.pop('light',0)
        medium = kwargs.pop('medium',0)
        heavy = kwargs.pop('heavy',0)
        
        # trait breakdown
        #----------------------------------------
        divines = kwargs.pop('divines',0)
        infused = kwargs.pop('infused',0)
        
        # kilt
        #----------------------------------------
        kilt = kwargs.pop('kilt',False)
        
        # mundus
        #----------------------------------------
        thief = kwargs.pop('thief',False)
        shadow = kwargs.pop('shadow',False)
        warrior = kwargs.pop('warrior',False)
        lover = kwargs.pop('lover',False)
        
        # critical, damage, resources
        #----------------------------------------
        critical = kwargs.pop('critical',.1)
        damage = kwargs.pop('damage',1500)
        resource = kwargs.pop('resource',0)
        
        
        # damage done multiplier
        
        
        
    
    
    def add_buff(self,**kwargs):
        
        
class parse:
    def __init__(self,eso_class):
